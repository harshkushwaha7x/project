# %%
import pandas as pd

# %%
df1 = pd.read_csv("text_files_data2.csv")

# %%
df_prompt  =  df1[
        (df1['Class'] == 'Class 10th') ]

df_prompt['Chapter'].tolist()
# Out:
# ['chapter-9 Heredity and Evolution',
#  'chapter-12 Electricity',
#  'chapter-8 How do Organisms',
#  'chapter-2 Acids, Bases',
#  'chapter-5 Periodic Classification',
#  'Mock Paper',
#  'chapter-10 Light – Reflection and Refraction',
#  'chapter-13 Magnetic Effects of Electric Current',
#  'chapter-6 Life Processes',
#  'chapter-3 Metals and Non-metals',
#  'chapter-1 Chemical Reactions',
#  'chapter-7 Control and Coordination',
#  'chapter-11 The Human Eye and the Colourful World',
#  'chapter-15 Our Environment',
#  'ncert-book-class-10-geography-chapter-1-in-english',
#  'ncert-book-class-10-economics-chapter-2-in-english',
#  'ncert-book-class-10-political-science-chapter-4-in-english',
#  'ncert-book-class-10-social-science-history-chapter-3-in-english',
#  'ncert-book-class-10-geography-chapter-6-in-english',
#  'ncert-book-class-10-political-science-chapter-3-in-english',
#  'ncert-book-class-10-economics-chapter-5-in-english',
# ...

# %%
df1
# Out:
#           Class  Subject                                Chapter  \
# 0    Class 10th  Science       chapter-9 Heredity and Evolution
# 1    Class 10th  Science                 chapter-12 Electricity
# 2    Class 10th  Science             chapter-8 How do Organisms
# 3    Class 10th  Science                 chapter-2 Acids, Bases
# 4    Class 10th  Science      chapter-5 Periodic Classification
# ..          ...      ...                                    ...
# 249  Class 11th  Biology       Chapter 12 Respiration in Plants
# 250  Class 11th  Biology                 Chapter 9 Biomolecules
# 251  Class 11th  Biology             Chapter 1 The Living World
# 252  Class 11th  Biology                Chapter 3 Plant Kingdom
# 253  Class 11th  Biology  Chapter 6 Anatomy of Flowering Plants
#
#                                              File_Data Board
# 0    9\nCHAPTER\nHeredity and\nEvolution\nWe have s...  CBSE
# 1    12\nCHAPTER\nElectricity\nElectricity has an i...  CBSE
# ...
